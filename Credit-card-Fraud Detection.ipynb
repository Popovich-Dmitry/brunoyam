# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Fraud = pd.read_csv('C:/Users/wwwpo/Documents/credit_dataset.csv')# Прочитали документ
Fraud # Вывели на экран несколько значений
# Out:
#        Unnamed: 0       ID GENDER CAR REALITY  NO_OF_CHILD    INCOME  \
# 0               0  5008806      M   Y       Y            0  112500.0
# 1               1  5008808      F   N       Y            0  270000.0
# 2               2  5008809      F   N       Y            0  270000.0
# 3               3  5008810      F   N       Y            0  270000.0
# 4               4  5008811      F   N       Y            0  270000.0
# ...           ...      ...    ...  ..     ...          ...       ...
# 25129       25129  5149828      M   Y       Y            0  315000.0
# 25130       25130  5149834      F   N       Y            0  157500.0
# 25131       25131  5149838      F   N       Y            0  157500.0
# 25132       25132  5150049      F   N       Y            0  283500.0
# 25133       25133  5150337      M   N       Y            0  112500.0
#
#                 INCOME_TYPE                 EDUCATION_TYPE  \
# 0                   Working  Secondary / secondary special
# ...

# %%
Fraud[Fraud['TARGET']==1] # Отдельно посмотрели на мошенников
# Out:
#        Unnamed: 0       ID GENDER CAR REALITY  NO_OF_CHILD    INCOME  \
# 508           508  5009628      F   N       N            0  238500.0
# 664           664  5009938      F   N       Y            2  157500.0
# 956           956  5010535      F   Y       N            2  135000.0
# 960           960  5010541      F   Y       N            2  135000.0
# 1177         1177  5010864      M   Y       Y            1  450000.0
# ...           ...      ...    ...  ..     ...          ...       ...
# 25129       25129  5149828      M   Y       Y            0  315000.0
# 25130       25130  5149834      F   N       Y            0  157500.0
# 25131       25131  5149838      F   N       Y            0  157500.0
# 25132       25132  5150049      F   N       Y            0  283500.0
# 25133       25133  5150337      M   N       Y            0  112500.0
#
#                 INCOME_TYPE                 EDUCATION_TYPE  \
# 508                 Working  Secondary / secondary special
# ...

# %%
Fraud = Fraud.drop(['HOUSE_TYPE'], axis = 1) # Т.к. мобильный телефон есть у всех, мы удалили строку

# %%
Fraud['EDUCATION_TYPE'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='EDUCATION_TYPE'>

# %%
sns.countplot(Fraud['EDUCATION_TYPE'])
# Out:
# C:\Users\wwwpo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EDUCATION_TYPE', ylabel='count'>

# %%
pd.crosstab(Fraud['EDUCATION_TYPE'],Fraud['TARGET']) 
# Academic degree(Ученая степень) - ни одного случая с мошенническими операциями
# Out:
# TARGET                             0    1
# EDUCATION_TYPE
# Academic degree                   14    0
# Higher education                7004  128
# Incomplete higher                972   21
# Lower secondary                  181    6
# Secondary / secondary special  16541  267

# %%
pd.crosstab(Fraud['NO_OF_CHILD'],Fraud['TARGET']) 
# Многодетные семьи не нарушают закон. Возможно, осознают риск оставить детей без родителей
# Out:
# TARGET           0    1
# NO_OF_CHILD
# 0            15635  273
# 1             6021   97
# 2             2675   40
# 3              301   11
# 4               56    1
# 5               18    0
# 7                2    0
# 14               3    0
# 19               1    0

# %%
pd.crosstab(Fraud['INCOME'],Fraud['TARGET'])
# Out:
# TARGET     0  1
# INCOME
# 27000.0    3  0
# 31500.0    8  0
# 32400.0    5  0
# 36000.0    4  1
# 36900.0    2  0
# ...       .. ..
# 945000.0   4  0
# 990000.0   4  0
# 1125000.0  3  0
# 1350000.0  6  0
# 1575000.0  8  0
#
# [195 rows x 2 columns]

# %%
pd.DataFrame(np.array(Fraud['INCOME'],Fraud['TARGET'])).plot.scatter(Fraud['INCOME'],Fraud['TARGET'])
plt.xlabel('годовой доход')
plt.ylabel('мошенничество')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22112/3349918654.py in <module>
# ----> 1 pd.DataFrame(np.array(Fraud['INCOME'],Fraud['TARGET'])).plot.scatter(Fraud['INCOME'],Fraud['TARGET'])
#       2 plt.xlabel('годовой доход')
#       3 plt.ylabel('мошенничество')
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1634             ...                       colormap='viridis')
#    1635         """
# -> 1636         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1637
#    1638     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
# ...

# %%
np.corrcoef(Fraud['INCOME'],Fraud['TARGET'])[0, 1]
# Out:
# 0.00652995976388145

# %%
pd.DataFrame(np.array(Fraud['INCOME'],Fraud['TARGET']))
plt.scatter(Fraud['INCOME'],Fraud['TARGET'])
plt.show()

# %%
sns.heatmap(Fraud.corr())
# Out:
# <AxesSubplot:>
