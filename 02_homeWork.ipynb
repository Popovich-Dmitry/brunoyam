# %%
import pandas as pd

# %%
Dota = pd.read_csv('https://github.com/Shakirov-ER/brunoyam-ds-SC372-2560/blob/main/data/dota_hero_stats.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1620/44907125.py in <module>
# ----> 1 Dota = pd.read_csv('https://github.com/Shakirov-ER/brunoyam-ds-SC372-2560/blob/main/data/dota_hero_stats.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# # Домашняя работа
#
# # Easy
# Открыть набор данных dota_hero_stats.csv из папки data.
#
# Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по Dota2.
#
# Пересчитаем число ног у героев игры Dota2! Сгруппируйте героев из датасэта по числу их ног (колонка legs), и посчитайте количество героев для каждого значения legs

# %%
Dota = pd.read_csv('C:/Users/wwwpo/Documents/dota_hero_stats.csv', index_col=0)

# %%
Dota['legs'].unique()
# Out:
# array([2, 4, 0, 6, 8], dtype=int64)

# %%
Dota['legs'].value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %% [markdown]
# # Normal
# Продолжим исследование героев Dota2. Сгруппируйте по колонкам attack_type и primary_attr и выберите самый распространённый набор характеристик. Выведите список героев с этим набором характеристик

# %%
Dota
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
df = Dota.groupby(['attack_type', 'primary_attr']).count()[['id']]
df[df.id == df.id.max()]
# Out:
#                           id
# attack_type primary_attr
# Ranged      int           40

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 'primary_attr'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3068/356070719.py in <module>
# ----> 1 Dota.groupby('attack_type', 'primary_attr').count().index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7625         if level is None and by is None:
#    7626             raise TypeError("You have to supply one of 'by' and 'level'")
# ...
